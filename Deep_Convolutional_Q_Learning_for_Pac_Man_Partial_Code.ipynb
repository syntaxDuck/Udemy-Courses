# %% [markdown]
# <a href="https://colab.research.google.com/github/syntaxDuck/Udemy-Courses/blob/main/Deep_Convolutional_Q_Learning_for_Pac_Man_Partial_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Convolutional Q-Learning for Pac-Man

# %% [markdown]
# ## Part 0 - Installing the required packages and importing the libraries

# %% [markdown]
# ### Installing Gymnasium

# %%
# !pip install gymnasium
# !pip install imageio
# !pip install "gymnasium[atari, accept-rom-license]"
# !pip install ale-py
# !brew install swig
# !pip install "gymnasium[box2d]"
# !pip install "imageio[ffmpeg]"
# !pip install "imageio[pyav]"
# !brew install ffmpeg
# Out:
# Requirement already satisfied: gymnasium in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: imageio in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (2.36.1)
# Requirement already satisfied: numpy in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from imageio) (2.2.1)
# Requirement already satisfied: pillow>=8.3.2 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from imageio) (11.1.0)
# Requirement already satisfied: gymnasium[accept-rom-license,atari] in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (1.0.0)
# WARNING: gymnasium 1.0.0 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium[accept-rom-license,atari]) (2.2.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium[accept-rom-license,atari]) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium[accept-rom-license,atari]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium[accept-rom-license,atari]) (0.0.4)
# Requirement already satisfied: ale-py>=0.9 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium[accept-rom-license,atari]) (0.10.1)
# Requirement already satisfied: ale-py in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (0.10.1)
# Requirement already satisfied: numpy>1.20 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from ale-py) (2.2.1)
# Warning: swig 4.3.0 is already installed and up-to-date.
# To reinstall 4.3.0, run:
#   brew reinstall swig
# Requirement already satisfied: gymnasium[box2d] in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium[box2d]) (2.2.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium[box2d]) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium[box2d]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from gymnasium[box2d]) (4.3.0)
# Requirement already satisfied: imageio[ffmpeg] in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (2.36.1)
# Requirement already satisfied: numpy in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from imageio[ffmpeg]) (2.2.1)
# Requirement already satisfied: pillow>=8.3.2 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from imageio[ffmpeg]) (11.1.0)
# Requirement already satisfied: imageio-ffmpeg in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from imageio[ffmpeg]) (0.5.1)
# Requirement already satisfied: psutil in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from imageio[ffmpeg]) (6.1.1)
# Requirement already satisfied: setuptools in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from imageio-ffmpeg->imageio[ffmpeg]) (75.2.0)
# Requirement already satisfied: imageio[pyav] in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (2.36.1)
# Requirement already satisfied: numpy in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from imageio[pyav]) (2.2.1)
# Requirement already satisfied: pillow>=8.3.2 in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from imageio[pyav]) (11.1.0)
# Requirement already satisfied: av in /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages (from imageio[pyav]) (14.0.1)
# Warning: ffmpeg 7.1_4 is already installed and up-to-date.
# To reinstall 7.1_4, run:
#   brew reinstall ffmpeg

# %% [markdown]
# ### Importing the libraries

# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# ## Part 1 - Building the AI

# %% [markdown]
# ### Creating the architecture of the Neural Network

# %%
class Network(nn.Module):
    def __init__(self, action_size, seed=42):
        super(Network, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.conv1 = nn.Conv2d(3, 32, kernel_size=8, stride=4)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.bn3 = nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(64, 128, kernel_size=3, stride=1)
        self.bn4 = nn.BatchNorm2d(128)
        self.fc1 = nn.Linear(128 * 10 * 10, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, action_size)

    def forward(self, state):
      x = F.relu(self.bn1(self.conv1(state)))
      x = F.relu(self.bn2(self.conv2(x)))
      x = F.relu(self.bn3(self.conv3(x)))
      x = F.relu(self.bn4(self.conv4(x)))
      x = x.view(x.size(0), -1)
      x = F.relu(self.fc1(x))
      x = F.relu(self.fc2(x))
      return self.fc3(x)

# %% [markdown]
# ## Part 2 - Training the AI

# %% [markdown]
# ### Setting up the environment

# %%
import ale_py
import gymnasium as gym
env = gym.make('MsPacmanDeterministic-v0', full_action_space = False)
state_shape = env.observation_space.shape
state_size = env.observation_space.shape[0]
number_actions = env.action_space.n
print('State shape: ', state_shape)
print('State size: ', state_size)
print('Number of actions: ', number_actions)
# Out:
# State shape:  (210, 160, 3)
# State size:  210
# Number of actions:  9
# /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment MsPacmanDeterministic-v0 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(
# A.L.E: Arcade Learning Environment (version 0.10.1+6a7e0ae)
# [Powered by Stella]

# %% [markdown]
# ### Initializing the hyperparameters

# %%
learning_rate = 5e-4
minibatch_size = 64
discount_factor = 0.99

# %% [markdown]
# ### Preprocessing the frames

# %%
from PIL import Image
from torchvision import transforms

def preprocess_frame(frame):
    frame = Image.fromarray(frame)
    preprocess = transforms.Compose([
        transforms.Resize((128, 128)),
        transforms.ToTensor(),
    ])
    return preprocess(frame).unsqueeze(0)

# %% [markdown]
# ### Implementing the DCQN class

# %%
class Agent(object):
  def __init__(self, action_size) -> None:
     self.device = torch.device("mps" if torch.mps.is_available() else "cpu")
     self.action_size = action_size
     self.local_qnetwork = Network(action_size).to(self.device)
     self.target_qnetwork = Network(action_size).to(self.device)
     self.optimizer = optim.Adam(self.local_qnetwork.parameters(), lr = learning_rate)
     self.memory = deque(maxlen=10000)

  def step(self, state, action, reward, next_state, done):
    state = preprocess_frame(state)
    next_state = preprocess_frame(next_state)
    self.memory.append((state, action, reward, next_state, done))
    if len(self.memory) > minibatch_size:
      experiences = random.sample(self.memory, k=minibatch_size)
      self.learn(experiences, discount_factor)

  def act(self, state, epsilon = 0.0):
    state = preprocess_frame(state).to(self.device)
    self.local_qnetwork.eval()
    with torch.no_grad():
      action_values = self.local_qnetwork(state)
    self.local_qnetwork.train()
    if random.random() > epsilon:
      return np.argmax(action_values.cpu().data.numpy())
    else:
      return random.choice(np.arange(self.action_size))

  def learn(self, experiences, discount_factor):
    states, actions, rewards, next_states, dones = zip(*experiences)
    states = torch.from_numpy(np.vstack(states)).float().to(self.device)
    actions = torch.from_numpy(np.vstack(actions)).long().to(self.device)
    rewards = torch.from_numpy(np.vstack(rewards)).float().to(self.device)
    next_states = torch.from_numpy(np.vstack(next_states)).float().to(self.device)
    dones = torch.from_numpy(np.vstack(dones)).type(torch.uint8).float().to(self.device)
    next_q_targets = self.target_qnetwork(next_states).detach().max(1)[0].unsqueeze(1)
    q_targets = rewards + (discount_factor * next_q_targets * (1 - dones))
    q_expected = self.local_qnetwork(states).gather(1, actions)
    loss = F.mse_loss(q_expected, q_targets)
    self.optimizer.zero_grad()
    loss.backward()
    self.optimizer.step()

# %% [markdown]
# ### Initializing the DCQN agent

# %%
agent = Agent(number_actions)

# %% [markdown]
# ### Training the DCQN agent

# %%
from datetime import datetime
number_episodes = 10000
maximum_number_timesteps_per_episode = 10000
epsilon_starting_value = 1.0
epsilon_final_value = 0.01
epsilon_decay_rate = 0.995
epsilon = epsilon_starting_value
scores_on_100_episodes = deque(maxlen = 100)

t1 = datetime.now()
for epsiode in range(1, number_episodes + 1):
  start_time = datetime.now()
  state, _ = env.reset()
  score = 0
  for timestep in range(maximum_number_timesteps_per_episode):
    action = agent.act(state, epsilon)
    next_state, reward, done, _, _ = env.step(action)
    agent.step(state, action, reward, next_state, done)
    state = next_state
    score += reward
    if done:
      break
  scores_on_100_episodes.append(score)
  epsilon = max(epsilon_final_value, epsilon_decay_rate * epsilon)
  print(f'\rEpisode: {epsiode}\tAverage Score: {np.mean(scores_on_100_episodes):.2f}\tEpsilon: {epsilon:.3f}\t Episode Time: {datetime.now()-start_time}', end = "")
  if epsiode % 100 == 0:
    print(f'\rEpisode: {epsiode}\tAverage Score: {np.mean(scores_on_100_episodes):.2f}\t Batch Time: {datetime.now()-t1}')
    t1 = datetime.now()
    epsilon += 0.1


  if np.mean(scores_on_100_episodes) >= 500.0:
    print(f'\nEnvironment solved in {epsiode-100} episodes!\tAverage Score: {np.mean(scores_on_100_episodes):.2f}')
    torch.save(agent.local_qnetwork.state_dict(), 'checkpoint.pth')
    break
# Out:
# Episode: 100	Average Score: 301.30	 Batch Time: 0:22:33.023486
# Episode: 200	Average Score: 333.70	 Batch Time: 0:23:32.136751
# Episode: 300	Average Score: 377.60	 Batch Time: 0:23:53.187003
# Episode: 400	Average Score: 453.40	 Batch Time: 0:24:14.593965
# Episode: 500	Average Score: 466.20	 Batch Time: 0:25:39.606451
# Episode: 600	Average Score: 420.80	 Batch Time: 0:22:09.567557
# Episode: 700	Average Score: 442.40	 Batch Time: 0:22:41.475633
# Episode: 800	Average Score: 422.20	 Batch Time: 0:22:11.387212
# Episode: 873	Average Score: 429.70	Epsilon: 0.185	 Episode Time: 0:00:13.179700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 16
#      14 score = 0
#      15 for timestep in range(maximum_number_timesteps_per_episode):
# ---> 16   action = agent.act(state, epsilon)
#      17   next_state, reward, done, _, _ = env.step(action)
#      18   agent.step(state, action, reward, next_state, done)
#
# Cell In[7], line 19, in Agent.act(self, state, epsilon)
#      18 def act(self, state, epsilon = 0.0):
# ---> 19   state = preprocess_frame(state).to(self.device)
#      20   self.local_qnetwork.eval()
#      21   with torch.no_grad():
#
# KeyboardInterrupt:

# %% [markdown]
# ## Part 3 - Visualizing the results

# %%
import glob
import io
import base64
import imageio
from IPython.display import HTML, display

def show_video_of_model(agent, env_name):
    env = gym.make(env_name, render_mode='rgb_array')
    state, _ = env.reset()
    done = False
    frames = []
    while not done:
        frame = env.render()
        frames.append(frame)
        action = agent.act(state)
        state, reward, done, _, _ = env.step(action)
    env.close()
    imageio.mimsave('video.mp4', frames, fps=30)

show_video_of_model(agent, 'MsPacmanDeterministic-v0')

def show_video():
    mp4list = glob.glob('*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")

show_video()
# Out:
# /Users/kameroncomer/.local/share/virtualenvs/ai-NVHVtFN8/lib/python3.11/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment MsPacmanDeterministic-v0 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
